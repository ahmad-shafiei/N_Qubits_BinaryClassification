# %%
import numpy as np

# Load .npy file
data1 = np.load("X_train.npy")
data2 = np.load("X_test.npy")
data3 = np.load("X_validation.npy")

data4 = np.load("Y_train.npy")
data5 = np.load("Y_test.npy")
data6 = np.load("Y_validation.npy")

data7 = np.load("theta_train.npy")
data8 = np.load("theta_test.npy")
data9 = np.load("theta_validation.npy")

# Save to .txt file
np.savetxt("X_train.txt", data1)
np.savetxt("X_test.txt", data2)
np.savetxt("X_validation.txt", data3)

np.savetxt("Y_train.txt", data4)
np.savetxt("Y_test.txt", data5)
np.savetxt("Y_validation.txt", data6)

np.savetxt("theta_train.txt", data7)
np.savetxt("theta_test.txt", data8)
np.savetxt("theta_validation.txt", data9)
